# %% [markdown]
# ## Ml Project 2

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge , Lasso
from sklearn.metrics import mean_squared_error , r2_score 
from sklearn.datasets import load_diabetes

# %%
df = pd.read_csv(r"C:\Users\air73\OneDrive\Documents\Full stack data science\diabetes.csv")

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
x = df[["Pregnancies","Glucose",	"BloodPressure", "SkinThickness" , "Insulin",	"BMI",	"DiabetesPedigreeFunction",	"Age"]]

# %%
y = df[["Outcome"]]

# %%
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size=0.2)

# %%
x_train
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 759            6      190             92              0        0  35.5
# 48             7      103             66             32        0  39.1
# 505           10       75             82              0        0  33.3
# 145            0      102             75             23        0   0.0
# 243            6      119             50             22      176  27.1
# ..           ...      ...            ...            ...      ...   ...
# 158            2       88             74             19       53  29.0
# 376            0       98             82             15       84  25.2
# 44             7      159             64              0        0  27.4
# 50             1      103             80             11       82  19.4
# 532            1       86             66             52       65  41.3
#
#      DiabetesPedigreeFunction  Age
# 759                     0.278   66
# 48                      0.344   31
# ...

# %%
x_test
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 578           10      133             68              0        0  27.0
# 222            7      119              0              0        0  25.2
# 661            1      199             76             43        0  42.9
# 266            0      138              0              0        0  36.3
# 390            1      100             66             29      196  32.0
# ..           ...      ...            ...            ...      ...   ...
# 643            4       90              0              0        0  28.0
# 708            9      164             78              0        0  32.8
# 253            0       86             68             32        0  35.8
# 654            1      106             70             28      135  34.2
# 386            5      116             74             29        0  32.3
#
#      DiabetesPedigreeFunction  Age
# 578                     0.245   36
# 222                     0.209   37
# ...

# %%
y_train
# Out:
#      Outcome
# 759        1
# 48         1
# 505        0
# 145        0
# 243        1
# ..       ...
# 158        0
# 376        0
# 44         0
# 50         0
# 532        0
#
# [614 rows x 1 columns]

# %%
y_test
# Out:
#      Outcome
# 578        0
# 222        0
# 661        1
# 266        1
# 390        0
# ..       ...
# 643        0
# 708        1
# 253        0
# 654        0
# 386        1
#
# [154 rows x 1 columns]

# %%
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.fit_transform(x_test)

# %%
ridge_model = Ridge()
lasso_model = Lasso()

# %%
#creating a ridge model 
rideg_model = ridge_model.fit(x_train_scaled , y_train)
ridge_model
# Out:
# Ridge()

# %%
lasso_model = lasso_model.fit(x_train_scaled , y_train)
lasso_model
# Out:
# Lasso()

# %%
#predicting the data from ridge model 
ridge_model.predict(x_test_scaled)
# Out:
# array([ 0.49902813,  0.44067401,  1.04821306,  0.6328627 ,  0.14588886,
#         0.99804944,  0.86118945,  0.38767032,  0.22396177,  0.14505781,
#         0.41740957,  0.49179146,  0.55458118,  0.45302829,  0.36158212,
#         0.33560079,  0.26808417,  0.69552223, -0.10669039,  0.96888143,
#         0.1430156 ,  0.45475895,  0.75902884,  0.50076361,  0.25588821,
#         0.28497092, -0.00651924,  0.56588248,  0.57351625,  0.13183619,
#         0.70501593,  0.36524922,  0.19561139,  0.3336151 ,  0.25428648,
#         0.46875262,  0.31725789,  0.22995937,  0.13914017,  0.77494497,
#         0.33190009,  0.24014671,  0.43622029,  0.68659539,  0.22623877,
#         0.07247551,  0.27315236,  0.52169607,  0.58020645,  0.14776581,
#         0.65860848,  0.37016171, -0.26252194,  0.3894943 , -0.06832255,
#         0.0070651 ,  0.07931813,  0.0823196 ,  0.33625952,  0.6210747 ,
#        -0.17835001,  0.70726937,  0.02070303,  0.10269197,  0.4106126 ,
# ...

# %%
#predicting the data from lasso model 
lasso_model.predict(x_test_scaled)
# Out:
# array([0.3485342, 0.3485342, 0.3485342, 0.3485342, 0.3485342, 0.3485342,
#        0.3485342, 0.3485342, 0.3485342, 0.3485342, 0.3485342, 0.3485342,
#        0.3485342, 0.3485342, 0.3485342, 0.3485342, 0.3485342, 0.3485342,
#        0.3485342, 0.3485342, 0.3485342, 0.3485342, 0.3485342, 0.3485342,
#        0.3485342, 0.3485342, 0.3485342, 0.3485342, 0.3485342, 0.3485342,
#        0.3485342, 0.3485342, 0.3485342, 0.3485342, 0.3485342, 0.3485342,
#        0.3485342, 0.3485342, 0.3485342, 0.3485342, 0.3485342, 0.3485342,
#        0.3485342, 0.3485342, 0.3485342, 0.3485342, 0.3485342, 0.3485342,
#        0.3485342, 0.3485342, 0.3485342, 0.3485342, 0.3485342, 0.3485342,
#        0.3485342, 0.3485342, 0.3485342, 0.3485342, 0.3485342, 0.3485342,
#        0.3485342, 0.3485342, 0.3485342, 0.3485342, 0.3485342, 0.3485342,
#        0.3485342, 0.3485342, 0.3485342, 0.3485342, 0.3485342, 0.3485342,
#        0.3485342, 0.3485342, 0.3485342, 0.3485342, 0.3485342, 0.3485342,
# ...

# %%
#Calculating the error in ridge model
mean_squared_error(y_test , ridge_model.predict(x_test_scaled))
# Out:
# 0.15849100152435355

# %%
#calculating the error for lasso model 
mean_squared_error(y_test ,lasso_model.predict(x_test_scaled))
# Out:
# 0.22769885739254117

# %%
# Calculating the R-Square for lasso model 
r2_lasso = r2_score(y_test , lasso_model.predict(x_test_scaled))            # y_test == y_true and model.predict(x_test_scaled)== y_predict
r2_lasso
# Out:
# -1.9648503982949705e-05

# %%
# Calculating the R-Square for Ridge model 
r2_ridge = r2_score(y_test , ridge_model.predict(x_test_scaled))
r2_ridge
# Out:
# 0.303931001453413

# %%
# Calculating the adjusted R-Square for lasso model
n = len(y_test)      # No of data points/rows
p = x.shape[1]       # No of predictors(independent variables i.e age , height , weight , gender) / coloumns
adj_r2_lasso = 1 - (1-r2_lasso) * (n-1) / (n-p-1)
adj_r2_lasso
# Out:
# -0.05519314635247863

# %%
# Calculating the adjusted R-Square for ridge model 
adj_r2_ridge = 1 - (1-r2_ridge) * (n-1) / (n-p-1)
adj_r2_ridge
# Out:
# 0.26552719463704955

# %%
# Calculating the RMSE for lasso model 
rmse_lasso = np.sqrt(mean_squared_error(y_test , lasso_model.predict(x_test_scaled)))
rmse_lasso
# Out:
# np.float64(0.47717801436417956)

# %%
# Calculating the RMSE for ridge model 
rmse_ridge = np.sqrt(mean_squared_error(y_test , ridge_model.predict(x_test_scaled)))
rmse_ridge
# Out:
# np.float64(0.3981092833938359)

# %%
import pickle
with open("diabetes_prediction.pkl" ,'wb') as file :
    pickle.dump((ridge_model , scaler),file)

# %% [markdown]
# ## POlynomial regression

# %%
data = pd.read_csv(r"C:\Users\air73\Downloads\Ice-cream-selling-data-csv_6UnYJ.csv")
data.columns
# Out:
# Index(['Temperature (°C)', 'Ice Cream Sales (units)'], dtype='object')

# %%
plt.scatter(data['Temperature (°C)'] , data['Ice Cream Sales (units)'])

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline

# %%
x = data[['Temperature (°C)']]
y =  data[['Ice Cream Sales (units)']]
polynomial_model = make_pipeline(PolynomialFeatures(degree=3), LinearRegression())      # This is how we create the polynimal model here degree 3 means it will create y = m1x1 + m2x2(square) + m3x3(cube) + c
polynomial_model2 = make_pipeline(PolynomialFeatures(degree=4), LinearRegression()) 
polynomial_model3 = make_pipeline(PolynomialFeatures(degree=5), LinearRegression()) 
polynomial_model4 = make_pipeline(PolynomialFeatures(degree=6), LinearRegression()) 
polynomial_model5 = make_pipeline(PolynomialFeatures(degree=7), LinearRegression()) 

polynomial_model.fit(x,y)
polynomial_model2.fit(x,y)
polynomial_model3.fit(x,y)
polynomial_model4.fit(x,y)
polynomial_model5.fit(x,y)
# Out:
# Pipeline(steps=[('polynomialfeatures', PolynomialFeatures(degree=7)),
#                 ('linearregression', LinearRegression())])

# %%
y_pred = polynomial_model.predict(x)

# %%
plt.scatter(data['Temperature (°C)'] , data['Ice Cream Sales (units)'])
plt.plot(x,polynomial_model.predict(x) , color = "red")                                         #Checking whether our degree suits 
plt.plot(x,polynomial_model2.predict(x) , color = "green") 
plt.plot(x,polynomial_model3.predict(x) , color = "blue")
plt.plot(x,polynomial_model4.predict(x) , color = "yellow")
plt.plot(x,polynomial_model5.predict(x) , color = "black")

# %%
#How to decide since all the lines looks same ----->> now we calculate the r2 score or MSER for each model and decide 
r2_score(y,polynomial_model.predict(x))
# Out:
# 0.9367011897445384

# %%
mean_squared_error(y,polynomial_model.predict(x))
# Out:
# 9.32724344567126

# %%
r2_score(y,polynomial_model2.predict(x))
# Out:
# 0.9438453407370606

# %%
mean_squared_error(y,polynomial_model2.predict(x))
# Out:
# 8.274534314947285

# %%
r2_score(y,polynomial_model3.predict(x))
# Out:
# 0.945283262189464

# %%
mean_squared_error(y,polynomial_model3.predict(x))
# Out:
# 8.062652869021331

# %%
r2_score(y,polynomial_model4.predict(x))
# Out:
# 0.9463965266611903

# %%
mean_squared_error(y,polynomial_model4.predict(x))
# Out:
# 7.8986104690883625

# %%
r2_score(y,polynomial_model5.predict(x))
# Out:
# 0.9521875881535858

# %%
mean_squared_error(y,polynomial_model5.predict(x))
# Out:
# 7.0452825766614255

# %% [markdown]
# ### so we can go with model 1
